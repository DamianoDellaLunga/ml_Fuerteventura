# %%
#load the data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
data=pd.read_excel("Remi_data.xlsx", sheet_name='Dataset_ST-B52')

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Unnamed: 0  Positions (m)      d18O_1m         dD_1m dexcess_1m  \
# 0      B52_R_01            0.0     -42.4356      -334.251    5.23343
# 1      B52_R_02           10.0     -43.3458      -341.603    5.16367
# 2      B52_R_03           20.0     -44.5687      -351.237    5.31216
# 3      B52_R_04           30.0     -43.5059      -343.985    4.06234
# 4      B52_R_05           40.0     -43.8518       -343.83    6.98442
# 5      B52_R_06           50.0     -44.0215      -344.848    7.32432
# 6      B52_R_07           60.0     -44.7015      -352.652    4.96033
# 7      B52_R_08           70.0     -43.5144       -342.68    5.43558
# 8      B52_R_09           80.0     -43.7688      -344.253    5.89808
# 9       Average            NaN      -43.746      -344.371    5.59715
# 10        Stdev            NaN     0.676935       5.35408    1.01161
# 11     Sampleww            NaN  d18O_meanww  ddeut_meanww  dexcessww
# 12  B52_R_01_01            0.0     -41.2695      -325.514    4.64203
# ...

# %%
df2=df[12:39]
print(df2.head())
print(df2.tail())
# Out:
#      Unnamed: 0  Positions (m)  d18O_1m    dD_1m dexcess_1m Fluorid_1m  \
# 12  B52_R_01_01            0.0 -41.2695 -325.514    4.64203   0.502148
# 13  B52_R_01_03            0.0 -42.8563  -336.72    6.13025   0.493684
# 14  B52_R_01_06            0.0  -43.181  -340.52    4.92801   0.546614
# 15   B52_R_02_0           10.0 -43.9973 -343.604    8.37451   0.421141
# 16  B52_R_02_03           10.0 -43.6905 -344.523    5.00098   0.520272
#
#      MSA_1m Chlorid_1m Bromid_1m Sulfat_1m Nitrat_1m Natrium_1m Magnesium_1m  \
# 12  7.32341    33.3316  0.643055   60.6494   53.8753    8.51479      1.46309
# 13  12.9664    28.0317  0.608171   47.4776   59.4494    7.77119      2.34418
# 14  7.24768    37.0232  0.637127   73.9545   63.2473    10.0525      3.26629
# 15  12.9519    36.3755  0.464877   58.3035   46.4871    14.5435      3.04409
# 16  8.29915    28.1715  0.785289   46.3977   49.4493    13.8341      2.90862
#
#    Calcium_1m
# 12    1.02252
# 13     1.0593
# 14    5.05013
# ...

# %%
import statsmodels.graphics.tsaplots as sgt

# %%
sgt.plot_pacf(df2.d18O_1m, lags = 10, alpha=.05, zero = False, method='ols')
plt.title("PACF of d18O", size = 20)
plt.show()

# %%
df2
# Out:
#      Unnamed: 0  Positions (m)  d18O_1m    dD_1m dexcess_1m Fluorid_1m  \
# 12  B52_R_01_01            0.0 -41.2695 -325.514    4.64203   0.502148
# 13  B52_R_01_03            0.0 -42.8563  -336.72    6.13025   0.493684
# 14  B52_R_01_06            0.0  -43.181  -340.52    4.92801   0.546614
# 15   B52_R_02_0           10.0 -43.9973 -343.604    8.37451   0.421141
# 16  B52_R_02_03           10.0 -43.6905 -344.523    5.00098   0.520272
# 17  B52_R_02_06           10.0 -42.3495 -336.681    2.11551    0.39375
# 18   B52_R_03_0           20.0 -45.1965 -356.815    4.75699   0.473234
# 19  B52_R_03_03           20.0 -45.7395 -359.321      6.595   0.406773
# 20  B52_R_03_06           20.0   -42.77 -337.576     4.5845   0.403569
# 21   B52_R_04_0           30.0 -42.7422 -336.921    5.01749   0.477513
# 22  B52_R_04_03           30.0 -44.0585 -349.977    2.49078   0.539252
# 23  B52_R_04_06           30.0  -43.717 -345.057    4.67874   0.457731
# ...

# %% [markdown]
# ### No significant coefficients

# %%
for i in range(1,10):
    r=random.randint(4,13)*3
    df3=df2.d18O_1m[r:r+3]
    a=df3.std()
    ls=[]
    if a is not 
    ls.append(a)
# Out:
# [0.5386585096329582]

# %%
# Out:
# None
